# %% [markdown]
# <a href="https://colab.research.google.com/github/eduardoalbertorg/UAG_reconocimiento_patrones/blob/main/16062022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
from google.colab.patches import cv2_imshow

# %%
from matplotlib import pyplot as plt

# %%
img=cv2.imread('imagesejemplo.jpg')

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7FF17E7DE4D0>

# %%
img.shape
# Out:
# (194, 259, 3)

# %%
plt.imshow(img)

# %%
y=img[0:100,0:100]

# %%
y.shape
# Out:
# (100, 100, 3)

# %%
cv2_imshow(y)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FF17DEAEE50>

# %%
y[10,10,2]=0

# %%
cv2_imshow(y)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FF17DEAE550>

# %%
y.shape
# Out:
# (100, 100, 3)

# %%
y[10,10,0]
# Out:
# 232

# %%
resize=cv2.resize(y,(400,400))
cv2_imshow(resize)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7FF17D9F7D10>

# %%
resize=cv2.resize(y,(40,40))
cv2_imshow(resize)
# Out:
# <PIL.Image.Image image mode=RGB size=40x40 at 0x7FF17DA20450>

# %%
img1=cv2.imread('fondo1.png')
img2=cv2.imread('fondo2.png')

# %%
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=415x237 at 0x7FF17DA02050>

# %%
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=416x237 at 0x7FF17DA02B10>

# %%
img1.shape
# Out:
# (237, 415, 3)

# %%
img2.shape
# Out:
# (237, 416, 3)

# %%
img3=img1[0:236,0:414]
img4=img2[0:236,0:414]

# %%
img3.shape
# Out:
# (236, 414, 3)

# %%
img4.shape
# Out:
# (236, 414, 3)

# %%
y1=img3-img4

# %%
resta=cv2.absdiff(img3,img4)

# %%
cv2_imshow(resta)
# Out:
# <PIL.Image.Image image mode=RGB size=414x236 at 0x7FF17D9EEC90>
